# %%
#!pip install pymupdf 
#!pip install dpath



#Lê o documento original
import fitz  
doc = fitz.open('./pag9_d.pdf')


#Lê o resultado do OCR
import json 
with open('pag9_d.json') as f:
    data = json.loads(f.read())

#Extrai as dimensões do documento
dims =  data['responses'][0]['fullTextAnnotation']['pages'][0]
WIDTH,HEIGHT = dims['width'], dims['height']
    
#Extrai as palavras do resultado do OCR
import dpath.util
results = []
for x,r in dpath.util.search(data,'responses/*/fullTextAnnotation/pages/*/blocks/*/paragraphs/*/words',yielded=True):
    results.append(r)


####################################################################################            
    
#Desenha retangulos no PDF com as palavras lidas correspondentes na posição correspondente
for page in doc:
    for n,words in enumerate(results):
        for word in words:
            verts = word['boundingBox']['normalizedVertices']
            x1, y1 = verts[0]['x'] * WIDTH, verts[0]['y'] * HEIGHT
            x2, y2 = verts[2]['x'] * WIDTH, verts[2]['y']  * HEIGHT
            rect = [x1,y1,x2,y2]
            text = ''.join(char.get('text',' ') for char in word['symbols'])
            page.add_freetext_annot(rect, text, fontsize=6.5,text_color=(1,0,0), fill_color=(1,1,1))

doc.save('./TEST_PAG9_PALAVRAS.pdf')

####################################################################################            

#Idem para "blocos"
results = []
for x,r in dpath.util.search(data,'responses/*/fullTextAnnotation/pages/*/blocks',yielded=True):
    results.append(r)
   
    
for page in doc:
    for n,blocks in enumerate(results):
        for block in blocks:
            verts = block['boundingBox']['normalizedVertices']
            x1, y1 = verts[0]['x'] * WIDTH, verts[0]['y'] * HEIGHT
            x2, y2 = verts[2]['x'] * WIDTH, verts[2]['y']  * HEIGHT
            rect = [x1,y1,x2,y2]
            page.add_freetext_annot(rect, '', fontsize=6.5, border_color=(0,1,0))
            
results = []


####################################################################################            

#Idem para "parágrafos"
for x,r in dpath.util.search(data,'responses/*/fullTextAnnotation/pages/*/blocks/*/paragraphs',yielded=True):
    results.append(r)
    

for page in doc:
    for n,blocks in enumerate(results):
        for block in blocks:
            verts = block['boundingBox']['normalizedVertices']
            x1, y1 = verts[0]['x'] * WIDTH, verts[0]['y'] * HEIGHT
            x2, y2 = verts[2]['x'] * WIDTH, verts[2]['y']  * HEIGHT
            rect = [x1,y1,x2,y2]
            page.add_freetext_annot(rect, '', fontsize=6.5, border_color=(0,0,1))

####################################################################################            
            
doc.save('./TEST_PAG9_ALL_OBJS.pdf')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 7
#       1 #!pip install pymupdf
#       2 #!pip install dpath
#       3
#       4
#       5
#       6 #Lê o documento original
# ----> 7 import fitz
#       8 doc = fitz.open('./pag9_d.pdf')
#      11 #Lê o resultado do OCR
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/fitz/__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/__init__.py:1
# ----> 1 from .events import *
#       2 from . import config
#       3 from .components import *
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/events/__init__.py:1
# ----> 1 from .clipboard import *
#       2 from .event_mixins import *
#       3 from .hash_change import *
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/events/clipboard.py:2
#       1 from .event_mixins import ClipboardDataMixin
# ----> 2 from ..dom import Event
#       4 __all__ = ['ClipboardEvent']
#       7 class ClipboardEvent(Event, ClipboardDataMixin):
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/dom.py:439
#     435         except KeyError:
#     436             pass
# --> 439 from . import dispatcher
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/dispatcher.py:15
#      12 from starlette.endpoints import WebSocketEndpoint
#      13 from starlette.websockets import WebSocket
# ---> 15 from . import config, server
#      16 from .async_utils import later_await
#      18 __all__ = ['react']
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/frontend/server.py:24
#      21 __all__ = ['route', 'run']
#      23 app: Any = Starlette(debug=config.DEBUG)
# ---> 24 app.mount(config.STATIC_ROUTE, StaticFiles(directory=config.STATIC_DIRECTORY), name=config.STATIC_NAME)
#      25 app.add_middleware(GZipMiddleware)
#      26 app.add_middleware(
#      27     CORSMiddleware,
#      28     allow_origins=["*"],
#    (...)
#      31     allow_headers=["*"],
#      32 )
#
# File ~/.cache/pypoetry/virtualenvs/tcc-Iqzz9cGZ-py3.8/lib/python3.8/site-packages/starlette/staticfiles.py:57, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      55 self.follow_symlink = follow_symlink
#      56 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 57     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory 'static/' does not exist

# %%
#Sequência desorganizada de palavras e números identificados
print(data['responses'][0]['fullTextAnnotation']['text'])
# Out:
# 8
# Receita do Imperio no exercicio de 1848-1849.
# DENOMINAÃ‡ÃƒO DAS RENDAS.
# RENDA GERAL.
# ORDINARIA.
# ImportaÃ§Ã£o.
# Direitos de consumo.
# Ditos de 1 por cento de reexportaÃ§Ã£o.
# Ditos de 1 por cento de baldeaÃ§Ã£o.
# Ditos de 5 por cento de reexportaÃ§Ã£o para a Africa.
# Ditos de 20 por cento de dita da polvora estrangeira idem..
# Ditos de reexportaÃ§Ã£o e baldeaÃ§Ã£o para a Africa (metade dos direitos de consumo).
# Expediente de 5 por cento dos generos estrangeiros despachados com carta de guia.
# Dito de meio por cento dos ditos do paiz...
# Armazenagem..
# Premio de assignados meio por cento.
# ImpugnaÃ§Ãµes por cento...
# Maltas.
# Despacho Maritimo.
# Ancoragem.
# 15 por cento das embarcaÃ§Ãµes estrangeiras que passa a nacionaes
# 5 por cento na compra e venda de embarcaÃ§Ãµes.
# ExportaÃ§Ã£o.
# Direitos de 7 por cento...
# Ditos de 2 por cento dos objectos exceptuados..
# LegitimaÃ§Ãµes..
# Sello do papel-Fixo.
# Ditos de meio por cento de ouro e prata amuedados.
# Ditos de 1 por cento do ouro em barras..
# Ditos de meio por cento dos diamantes..
# Ditos de 15 por cento dos couros (em S. Pedro)
# Premio de meio por cento de assignados (idem).
# Expediente das capatazias
# Multas.
# d
# Interior.
# Renda do Correio Geral..
# Dita da Casa da Moeda
# Dita da Typographia Nacional
# Dita da Fabrica da polvora.
# Dita da Fabrica de ferro de Ypanema.
# Dita dos Arsenaes.
# Dita da Casa de correcÃ§Ã£o.
# Dita de terrenos diamantinos.
# Dita de Proprios nacionaes.
# FÃ³ros de terrenos e de marinhas
# Laudemios..
# Sisa dos bens de raiz..
# Decima de huma legua alÃ©m da demarcaÃ§Ã£o
# Dita addicional das CorporaÃ§Ãµes de mÃ£o morta.
# Direitos novos e velhos e de Chancellaria.
# Joias das Ordens honorificas...
# Dizima da Chancellaria..
# Matriculas dos Cursos Juridicos
# Ditas das Escolas de Medicina
# Multas por infracÃ§Ã£o de Regulamentos
# Proporcional.
# Premios de depositos publicos..
# Descontos nos vencimentos recebidos dos cofres publicos
# Patentes dos despachantes e corretores...
# 343.696139
# 295.408836
# ARRECADADA.
# 14.720.886614
# 62. 547 717
# 60.028847
# 11.010870
# 48.883 71
# 176.603694
# 19.119790
# 198.879121
# 109.499664
# 825003
# 46.729508
# 485.863726
# 57.128397
# 30.982793
# 3.598.361753
# 78.417082
# 1.431012
# 734098
# 12.829653
# 123.971D532
# 1.918173
# 15.488272
# 1.8794391
# 129.502881
# 1.082488
# 34.446840
# 3.331741
# 20.14568
# 9.112211
# 6.832890
# 4.796900
# 73.614706
# 3.134749
# 3.124386
# 2.415600
# 48.6880185
# 84.152878
# 13.020160
# 46.676D453
# 49.052000
# 22.040000
# 4.116D815
# 275 200
# POR
# ARRECADAR.
# 639.104975
# 6.488325
# 3384066
# 8.469430
# 201966
# 1.036.647137 11.5430159
# 2.515160
# 6.9984803
# 3174881
# 766743
# 3.963299
# 4.226 367
# SEDOSA
# 4.870715
